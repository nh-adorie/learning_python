# %% [markdown]
# ## Preparation

# %%
import pandas as pd
import kagglehub 
import matplotlib.pyplot as plt
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 5
#       3 import matplotlib.pyplot as plt
#       4 import os
# ----> 5 import plotly.express as px
#
# ModuleNotFoundError: No module named 'plotly'

# %%
# Download latest version
path = kagglehub.dataset_download("kyanyoga/sample-sales-data")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 77.5k/77.5k [00:00<00:00, 33.3MB/s]
# Extracting files...
# Path to dataset files: /home/gitpod/.cache/kagglehub/datasets/kyanyoga/sample-sales-data/versions/1

# %%
all_files = os.listdir('/home/gitpod/.cache/kagglehub/datasets/kyanyoga/sample-sales-data/versions/1')
for file in all_files:
    print(file)
# Out:
# sales_data_sample.csv

# %%
raw = pd.read_csv(
    '/home/gitpod/.cache/kagglehub/datasets/kyanyoga/sample-sales-data/versions/1/sales_data_sample.csv',
    encoding='latin1'
)

# %% [markdown]
# ## Explore the data

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
describe = raw.describe()
describe.style.background_gradient(cmap = "Greens")

# supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Grays', 'Grays_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'berlin', 'berlin_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_grey', 'gist_grey_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gist_yerg', 'gist_yerg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'grey', 'grey_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'managua', 'managua_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'vanimo', 'vanimo_r', 'viridis', 'viridis_r', 'winter', 'winter_r'
# Out:
# <style type="text/css">
# #T_5a860_row0_col0 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_5a860_row0_col1, #T_5a860_row0_col2, #T_5a860_row0_col3, #T_5a860_row0_col5, #T_5a860_row0_col6, #T_5a860_row0_col7, #T_5a860_row0_col8, #T_5a860_row7_col0, #T_5a860_row7_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_5a860_row0_col4 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_5a860_row1_col0, #T_5a860_row5_col0 {
#   background-color: #00491d;
#   color: #f1f1f1;
# }
# #T_5a860_row1_col1, #T_5a860_row4_col1, #T_5a860_row5_col1, #T_5a860_row7_col3 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_5a860_row1_col2 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# ...

# %%
null = pd.DataFrame(raw.isnull().sum())
null.style.background_gradient(cmap = "Greens")
# Out:
# <style type="text/css">
# #T_554e6_row0_col0, #T_554e6_row1_col0, #T_554e6_row2_col0, #T_554e6_row3_col0, #T_554e6_row4_col0, #T_554e6_row5_col0, #T_554e6_row6_col0, #T_554e6_row7_col0, #T_554e6_row8_col0, #T_554e6_row9_col0, #T_554e6_row10_col0, #T_554e6_row11_col0, #T_554e6_row12_col0, #T_554e6_row13_col0, #T_554e6_row14_col0, #T_554e6_row15_col0, #T_554e6_row17_col0, #T_554e6_row20_col0, #T_554e6_row22_col0, #T_554e6_row23_col0, #T_554e6_row24_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_554e6_row16_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_554e6_row18_col0 {
#   background-color: #50b264;
#   color: #f1f1f1;
# }
# #T_554e6_row19_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_554e6_row21_col0 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# </style>
# <table id="T_554e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
columns = raw.columns
number_unique = pd.DataFrame(raw[columns].nunique())
number_unique.style.background_gradient(cmap = "Greens")
# Out:
# <style type="text/css">
# #T_a5325_row0_col0 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_a5325_row1_col0 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_a5325_row2_col0 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_a5325_row3_col0, #T_a5325_row18_col0, #T_a5325_row20_col0 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_a5325_row4_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a5325_row5_col0 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_a5325_row6_col0, #T_a5325_row7_col0, #T_a5325_row8_col0, #T_a5325_row9_col0, #T_a5325_row10_col0, #T_a5325_row16_col0, #T_a5325_row21_col0, #T_a5325_row24_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_a5325_row11_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_a5325_row12_col0 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_a5325_row13_col0, #T_a5325_row14_col0, #T_a5325_row15_col0 {
# ...

# %% [markdown]
# ## RFM analysis

# %% [markdown]
# RFM analysis is a customer segmentation technique that analyzes customer behavior based on **Recency, Frequency, and Monetary Value**. It helps businesses understand customer spending patterns, predict future behavior, and personalize marketing efforts.

# %% [markdown]
# **Recency:**
# How recently a customer made a purchase. A more recent purchase suggests a higher likelihood of future purchases.
#
# **Frequency:**
# How often a customer makes purchases. Frequent purchases indicate a loyal customer with established spending habits.
#
# **Monetary Value:**
# The total amount of money a customer spends. A higher monetary value suggests a more valuable customer.

# %%
fig = px.pie(data, names='COUNTRY', title='Country Pie Chart')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 fig = px.pie(data, names='COUNTRY', title='Country Pie Chart')
#       2 fig.show()
#
# NameError: name 'px' is not defined
